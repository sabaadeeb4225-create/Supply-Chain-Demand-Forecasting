# %%
pip install pandas
# Out:
# hello

# %%
import pandas as pd
data={'name':['Tom','Jerry','Mickey','Donald'],
      'age':[20,21,19,18],}
df=pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 data={'name':['Tom','Jerry','Mickey','Donald'],
#       3       'age':[20,21,19,18],}
#       4 df=pd.DataFrame(data)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip uninstall pandas -y
# Out:
# Found existing installation: pandas 3.0.3
# Uninstalling pandas-3.0.3:
#   Successfully uninstalled pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall pandas -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping pandas as it is not installed.

# %%
pip cache purge
# Out:
# Files removed: 6 (1.9 MB)
# Directories removed: 0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas==2.2.3
# Out:
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3.tar.gz (4.4 MB)
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/4.4 MB ? eta -:--:--
#      ----------------------------------- ---- 3.9/4.4 MB 18.9 MB/s eta 0:00:01
#      -------------------------------------- - 4.2/4.4 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------- 4.4/4.4 MB 8.0 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [62 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 178, in prepare_metadata_for_build_wheel
#           whl_basename = backend.build_wheel(metadata_directory, config_settings)
#         File "C:\Users\Latitude\AppData\Local\Temp\pip-build-env-jogbyzmx\overlay\Lib\site-packages\mesonpy\__init__.py", line 1048, in wrapper
#           return func(*args, **kwargs)
#         File "C:\Users\Latitude\AppData\Local\Temp\pip-build-env-jogbyzmx\overlay\Lib\site-packages\mesonpy\__init__.py", line 1112, in build_wheel
#           with _project(config_settings) as project:
#                ~~~~~~~~^^^^^^^^^^^^^^^^^
#         File "C:\Users\Latitude\AppData\Local\Python\pythoncore-3.14-64\Lib\contextlib.py", line 141, in __enter__
#           return next(self.gen)
#         File "C:\Users\Latitude\AppData\Local\Temp\pip-build-env-jogbyzmx\overlay\Lib\site-packages\mesonpy\__init__.py", line 986, in _project
#           with Project.with_temp_working_dir(
#                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#                   build_dir=settings.get('builddir'),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   meson_args=typing.cast(MesonArgs, meson_args),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   editable_verbose=bool(settings.get('editable-verbose'))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ) as project:
#           ^
#         File "C:\Users\Latitude\AppData\Local\Python\pythoncore-3.14-64\Lib\contextlib.py", line 141, in __enter__
#           return next(self.gen)
#         File "C:\Users\Latitude\AppData\Local\Temp\pip-build-env-jogbyzmx\overlay\Lib\site-packages\mesonpy\__init__.py", line 831, in with_temp_working_dir
#           yield cls(source_dir, tmpdir, build_dir, meson_args, editable_verbose)
#                 ~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Latitude\AppData\Local\Temp\pip-build-env-jogbyzmx\overlay\Lib\site-packages\mesonpy\__init__.py", line 652, in __init__
#           _check_meson_version()
#           ~~~~~~~~~~~~~~~~~~~~^^
#         File "C:\Users\Latitude\AppData\Local\Temp\pip-build-env-jogbyzmx\overlay\Lib\site-packages\mesonpy\__init__.py", line 1027, in _check_meson_version
#           meson_version = subprocess.run(['meson', '--version'], check=False, text=True, capture_output=True).stdout
#                           ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Latitude\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 555, in run
#           with Popen(*popenargs, **kwargs) as process:
#                ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Latitude\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 1039, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#           ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                               pass_fds, cwd, env,
#                               ^^^^^^^^^^^^^^^^^^^
#           ...<5 lines>...
#                               gid, gids, uid, umask,
#                               ^^^^^^^^^^^^^^^^^^^^^^
#                               start_new_session, process_group)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Latitude\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py", line 1553, in _execute_child
#           hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                              ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                                    # no special security
#                                    ^^^^^^^^^^^^^^^^^^^^^
#           ...<4 lines>...
#                                    cwd,
#                                    ^^^^
#                                    startupinfo)
#                                    ^^^^^^^^^^^^
#       OSError: [WinError 4551] An Application Control policy has blocked this file
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> pandas
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----------- ---------------------------- 2.9/9.9 MB 18.7 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.9 MB 11.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.9 MB 9.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 8.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 6.5 MB/s  0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Latitude\Desktop\project3\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
